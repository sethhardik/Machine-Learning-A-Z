# %%
# data visualization 
# pandas built in methods 
import numpy as np 
import pandas as pd
# %matplotlib inline

# %%
df1=pd.read_csv("/home/hardik/Desktop/datasets/data/pew.csv")

# %%
df1.head()
# Out:
#              religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# 0            Agnostic     27       34       60       81       76      137
# 1             Atheist     12       27       37       52       35       70
# 2            Buddhist     27       21       30       34       33       58
# 3            Catholic    418      617      732      670      638     1116
# 4  Don’t know/refused     15       14       15       11       10       35
#
#    $75-100k  $100-150k  >150k  Don't know/refused
# 0       122        109     84                  96
# 1        73         59     74                  76
# 2        62         39     53                  54
# 3       949        792    633                1489
# 4        21         17     18                 116

# %%
df1=pd.melt(df1,id_vars="religion",var_name="income",value_name="count")

# %%
df1.head()
# Out:
#              religion income  count
# 0            Agnostic  <$10k     27
# 1             Atheist  <$10k     12
# 2            Buddhist  <$10k     27
# 3            Catholic  <$10k    418
# 4  Don’t know/refused  <$10k     15

# %%
df1["count"].hist(bins=10)  # histogram

# %%
#area plot
df2["count"].plot(kind="area",alpha=0.5) #alpha makes the plot more transparent
#df2 made niche dekho niche

# %%
df2=df1.head(20)
df2["count"].plot(kind="bar")

# %%
df3.plot(kind="scatter",x="a",y="b")      #just representaion of the scatter plot using pandas

# %%
df3=pd.DataFrame(np.random.randn(1000,2),columns=["a","b"])
df3.head()
# Out:
#           a         b
# 0 -1.596071  0.314405
# 1  0.474151  0.885834
# 2  2.408930 -0.534198
# 3  0.445867  2.318708
# 4  0.283860 -2.252268

# %%
df3.plot(kind="hexbin",x="a",y="b",gridsize=20)  #creates hex bin typically like scatter plot

# %%
#kde plot
df3.plot(kind="kde")     #kernal density estimation
