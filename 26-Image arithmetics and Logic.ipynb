# %%
#image addition
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
img1=cv2.imread("OUTPUTS/test image.jpg",cv2.IMREAD_UNCHANGED)

# %%
img2=cv2.imread("OUTPUTS/img.jpg",cv2.IMREAD_UNCHANGED)

# %%
add=img1+img2
plt.imshow(add)

# %%
add2=cv2.add(img1,img2)
plt.imshow(add2)

# %%
add3=cv2.addWeighted(img1,0.6,img2,0.4)
