# %%
import matplotlib.pyplot as plt 
import numpy as np
# %matplotlib inline
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-3331543c8957> in <module>
#       2 import numpy as np
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 4 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
img=cv2.imread("OUTPUTS/test image.jpg",cv2.IMREAD_GRAYSCALE)    #gets image in gray scale form

# %%
plt.imshow(img,cmap="gray")

# %%
plt.imshow(img,cmap="gray",interpolation="bicubic") #slightly blurred image

# %%
#save image 
cv2.imwrite("OUTPUTS/test file gray.jpg",img)
# Out:
# True

# %%
img2=cv2.imread("OUTPUTS/test image.jpg",cv2.IMREAD_UNCHANGED)    #using differnet filters 
plt.imshow(img2,cmap="gray")
